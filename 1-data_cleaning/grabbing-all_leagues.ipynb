# %% [markdown]
# ## Grabbing the Data
# -----

# %% [markdown]
# ### Setup:
# ---

# %%
# Import dependencies
import requests
from bs4 import BeautifulSoup
import json
from jsonpath_ng.ext import parse
import pandas as pd

# %%
# Create funtion for grabbing json sections
def getJSONSection(json_data, section):
    return [obj for obj in json_data if obj['name'] == section]

# %%
# Create function for grabbing json values
def getJSONValue(json_data, section, stat):
    section_data = getJSONSection(json_data['splits']['categories'], section)
    stat_data = getJSONSection(section_data[0]['stats'], stat)
    return stat_data[0]['displayValue']

# %% [markdown]
# ### Grab Data:
# ---

# %%
# converts team name retrieved from statistics API to the team name used by the league for looking up player photos
def getTeamUrl(team_name):
    # laliga
    if (team_name == 'Real Sociedad'):
        return 'real-sociedad'
    if (team_name == 'Villarreal'):
        return 'villarreal-cf'
    if (team_name == 'Valencia'):
        return 'valencia-cf'
    if (team_name == 'Almería'):
        return 'ud-almeria'
    if (team_name == 'Mallorca'):
        return 'rcd-mallorca'
    if (team_name == 'Sevilla'):
        return 'sevilla-fc'
    if (team_name == 'Athletic Club'):
        return 'athletic-club'
    if (team_name == 'Rayo Vallecano'):
        return 'rayo-vallecano'
    if (team_name == 'Cádiz'):
        return 'cadiz-cf'
    if (team_name == 'Atletico Madrid'):
        return 'atletico-de-madrid'
    if (team_name == 'Granada'):
        return 'granada-cf'
    if (team_name == 'Real Madrid'):
        return 'real-madrid'
    if (team_name == 'Real Betis'):
        return 'real-betis'
    if (team_name == 'Celta Vigo'):
        return 'rc-celta'
    if (team_name == 'Getafe'):
        return 'getafe-cf'
    if (team_name == 'Osasuna'):
        return 'c-a-osasuna'
    if (team_name == 'Girona'):
        return 'girona-fc'
    if (team_name == 'Las Palmas'):
        return 'ud-las-palmas'
    if (team_name == 'Barcelona'):
        return 'fc-barcelona'
    if (team_name == 'Alavés'):
        return 'd-alaves'

    # bundesliga
    if (team_name == 'TSG Hoffenheim'):
          return 'tsg-hoffenheim'
    if (team_name == '1. FC Union Berlin'):
        return '1-fc-union-berlin'
    if (team_name == 'Borussia Dortmund'):
        return 'borussia-dortmund'
    if (team_name == 'Bayern Munich'):
        return 'fc-bayern-muenchen'
    if (team_name == 'FC Cologne'):
        return '1-fc-koeln'
    if (team_name == 'VfB Stuttgart'):
        return 'vfb-stuttgart'
    if (team_name == 'Eintracht Frankfurt'):
        return 'eintracht-frankfurt'
    if (team_name == '1. FC Heidenheim 1846'):
        return '1-fc-heidenheim-1846'
    if (team_name == 'RB Leipzig'):
        return 'rb-leipzig'
    if (team_name == 'Borussia Monchengladbach'):
        return 'borussia-moenchengladbach'
    if (team_name == 'SC Freiburg'):
        return 'sport-club-freiburg'
    if (team_name == 'Mainz'):
        return '1-fsv-mainz-05'
    if (team_name == 'Bayer Leverkusen'):
        return 'bayer-04-leverkusen'
    if (team_name == 'Werder Bremen'):
        return 'sv-werder-bremen'
    if (team_name == 'VfL Bochum'):
        return 'vfl-bochum-1848'
    if (team_name == 'VfL Wolfsburg'):
        return 'vfl-wolfsburg'
    if (team_name == 'FC Augsburg'):
        return 'fc-augsburg'
    if (team_name == 'SV Darmstadt 98'):
        return 'sv-darmstadt-98'

    # liga mx
    if (team_name == 'Pumas UNAM'):
        return "18/pumas"
    if (team_name == 'Monterrey'):
         return "14/monterrey"
    if (team_name == 'FC Juarez'):
         return "11790/fc-juarez"
    if (team_name == 'Pachuca'):
         return "11/pachuca"
    if (team_name == 'Querétaro'):
         return "12037/queretaro"
    if (team_name == 'Mazatlán FC'):
         return "12043/mazatlan-fc"
    if (team_name == 'Tigres UANL'):
        return '16/tigres'
    if (team_name == 'León'):
        return '9/leon'
    if (team_name == 'América'):
        return '1/america'
    if (team_name == 'Cruz Azul'):
        return '12566/cruz-azul'
    if (team_name == 'Atlético de San Luis'):
        return '11220/atletico-de-san-luis'
    if (team_name == 'Tijuana'):
        return '5/tijuana'
    if (team_name == 'Puebla'):
        return '11550/puebla'
    if (team_name == 'Guadalajara'):
        return '7/guadalajara'
    if (team_name == 'Toluca'):
        return '17/toluca'
    if (team_name == 'Atlas'):
        return '10445/atlas'
    if (team_name == 'Santos'):
        return '15/santos-laguna'
    if (team_name == 'Necaxa'):
        return '29/necaxa'
    

    # ligue 1
    if (team_name == 'Metz'):
          return "fc-metz"
    if (team_name == 'Nice'):
          return "ogc-nice"
    if (team_name == 'Paris Saint-Germain'):
         return "paris-saint-germain"
    if (team_name == 'Lille'):
        return "losc-lille"
    if (team_name == 'Lyon'):
          return "olympique-lyonnais"
    if (team_name == 'Stade Rennais'):
         return "stade-rennais-fc"
    if (team_name == 'Nantes'):
          return "fc-nantes"
    if (team_name == 'Montpellier'):
         return "montpellier-herault-sc"
    if (team_name == 'Strasbourg'):
        return 'rc-strasbourg-alsace'
    if (team_name == 'Clermont Foot'):
        return 'clermont-foot-63'
    if (team_name == 'Lens'):
        return 'rc-lens'
    if (team_name == 'Marseille'):
        return 'olympique-de-marseille'
    if (team_name == 'Le Havre AC'):
        return 'havre-ac'
    if (team_name == 'Brest'):
        return 'stade-brestois-29'
    if (team_name == 'Lorient'):
        return 'fc-lorient'
    if (team_name == 'AS Monaco'):
        return 'as-monaco'
    if (team_name == 'Stade de Reims'):
        return 'stade-de-reims'
    if (team_name == 'Toulouse'):
        return 'toulouse-fc'
    

    # serie A
    if (team_name == 'Hellas Verona'):
         return "VERONA"
    if (team_name == 'Genoa'):
         return "GENOA"
    if (team_name == 'Sassuolo'):
         return "SASSU"
    if (team_name == 'Bologna'):
         return "BOLO"
    if (team_name == 'Fiorentina'):
         return "FIORE"
    if (team_name == 'AS Roma'):
         return "ROMA"
    if (team_name == 'AC Milan'):
         return "MILAN"
    if (team_name == 'Atalanta'):
         return "ATALAN"
    if (team_name == 'Cagliari'):
         return "CAGLIA"
    if (team_name == 'Monza'):
        return 'MONZA'
    if (team_name == 'Internazionale'):
        return 'INTER'
    if (team_name == 'Udinese'):
        return 'UDINES'
    if (team_name == 'Salernitana'):
        return 'SALER'
    if (team_name == 'Lazio'):
        return 'LAZIO'
    if (team_name == 'Juventus'):
        return 'JUVE'
    if (team_name == 'Frosinone'):
        return 'FROSI'
    if (team_name == 'Empoli'):
        return 'EMPOLI'
    if (team_name == 'Torino'):
        return 'TORINO'
    if (team_name == 'Lecce'):
        return 'LECCE'
    if (team_name == 'Napoli'):
        return 'NAPOLI'

# %%
soccer_leagues = [
    {
        'display': 'MLS',
        'url': 'http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes?lang=en&region=us&limit=1000'
    },
    {
        'display': 'MLS',
        'url': 'http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes?lang=en&region=us&limit=1000&page=2'
    },
    {
        'display': 'NWSL',
        'url': 'http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.nwsl/seasons/2023/athletes?lang=en&region=us&limit=1000'
    },
    {
        'display': 'Premier League',
        'url': 'http://sports.core.api.espn.com/v2/sports/soccer/leagues/eng.1/seasons/2023/athletes?lang=en&region=us&limit=1000'
    },
    {
        'display': 'LALIGA',
        'url': 'http://sports.core.api.espn.com/v2/sports/soccer/leagues/esp.1/seasons/2023/athletes?lang=en&region=us&limit=1000'
    },
    {
        'display': 'LALIGA',
        'url': 'http://sports.core.api.espn.com/v2/sports/soccer/leagues/esp.1/seasons/2023/athletes?lang=en&region=us&limit=1000&page=2'
    },
    {
        'display': 'Bundesliga',
        'url': 'http://sports.core.api.espn.com/v2/sports/soccer/leagues/ger.1/seasons/2023/athletes?lang=en&region=us&limit=1000'
    },
    {
        'display': 'Bundesliga',
        'url': 'http://sports.core.api.espn.com/v2/sports/soccer/leagues/ger.1/seasons/2023/athletes?lang=en&region=us&limit=1000&page=2'
    },
    {
        'display': 'Liga MX',
        'url': 'https://sports.core.api.espn.com/v2/sports/soccer/leagues/mex.1/seasons/2023/athletes?lang=en&region=us&limit=1000'
    },
    {
        'display': 'Ligue 1',
        'url': 'https://sports.core.api.espn.com/v2/sports/soccer/leagues/fra.1/seasons/2023/athletes?lang=en&region=us&limit=1000'
    },
    {
        'display': 'Serie A',
        'url': 'https://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes?lang=en&region=us&limit=1000'
    }
]

# %%
selected_leagues = ['MLS','NWSL','Premier League','LALIGA','Bundesliga','Liga MX','Ligue 1','Serie A']

# %%
#Setup for grabbing data

#Setup lists for stats
names = []
teams = []
leagues = []
positions = []
jersey_numbers = []
goals = []
assists = []
yellow_cards = []
red_cards = []
shots = []
shots_og = []
saves = []
clean_sheets = []
goals_against = []
photo_urls = []
heights = []
weights = []
birthdates = []
nationalities = []

for league in soccer_leagues:
   if (league['display'] in selected_leagues):
     athlete_list_results_json = requests.get(league['url']).json()
    
     #Loop through players
     for athlete in range(len(athlete_list_results_json['items'])):

       athlete_results = requests.get(athlete_list_results_json['items'][athlete]['$ref'])
       athlete_results_json = athlete_results.json()
       if ('statistics' in athlete_results_json and 'team' in athlete_results_json):  
         print(athlete_list_results_json['items'][athlete]['$ref'])
         team_results = requests.get(athlete_results_json['team']['$ref'])
         team_results_json = team_results.json()

         athlete_stats_results = requests.get(athlete_results_json['statistics']['$ref'])
         athlete_stats_results_json = athlete_stats_results.json()
        
         #Grab images:
         #premier league
         if league['display'] == 'Premier League':
           try:
             name_search_url = f"https://footballapi.pulselive.com/search/PremierLeague/?terms={athlete_results_json['displayName']}&type=player&size=1&start=0&fullObjectResponse=true"
             name_search_result = requests.get(name_search_url, headers = {"origin": "https://www.premierleague.com"})
             name_search_result_json = name_search_result.json()

             image_id = name_search_result_json['hits']['hit'][0]['response']['altIds']['opta']
             image_url = f"https://resources.premierleague.com/premierleague/photos/players/250x250/{image_id}.png"
           except:
             image_url = 'N/A'

         #laliga
         elif league['display'] == 'LALIGA':
           try:
             club_squad_url = f"https://www.laliga.com/en-US/clubs/{getTeamUrl(team_results_json['displayName'])}/squad"
             club_squad_results = requests.get(club_squad_url)
             club_squad_results_parsed = BeautifulSoup(club_squad_results.content.decode('utf-8'))
             club_squad_json = json.loads(club_squad_results_parsed.body.find('script', attrs={'id': '__NEXT_DATA__'}).text)
             player_element = [obj for obj in club_squad_json['props']['pageProps']['squad']['squads'] if ('shirt_number' in obj) and (str(obj['shirt_number'])) == athlete_results_json['jersey']]
             image_url =  player_element[0]['photos']['002']['512x512']
           except:
             image_url = 'N/A'

         # bundesliga
         elif league['display'] == 'Bundesliga':
           try:
             club_squad_url = f"https://www.bundesliga.com/en/bundesliga/clubs/{getTeamUrl(team_results_json['displayName'])}"
             club_squad_results = requests.get(club_squad_url)
             club_squad_results_parsed = BeautifulSoup(club_squad_results.content.decode('utf-8'))
             club_squad_json = json.loads(club_squad_results_parsed.body.find('script', attrs={'id': 'serverApp-state'}).text)
             jsonpath_expr = parse(f"$..players.*[?(@.shirtNumber={athlete_results_json['jersey']})]")
             match = [items.value['playerImages']['FACE_CIRCLE'].replace('-circle', '') for items in jsonpath_expr.find(club_squad_json)]
             image_url = match[0]
           except:
             image_url = 'N/A'

         # mls
         elif league['display'] == 'MLS':
           try:
             image_url = athlete_results_json['headshot']['href'] if 'headshot' in athlete_results_json else 'N/A'
           except:
             image_url = 'N/A'

         # nwsl
         elif league['display'] == 'NWSL':
           try:
             base_url = 'https://d2nkt8hgeld8zj.cloudfront.net'
             player_list_url = f'{base_url}/services/nwsl.ashx/players'

             player_list_results = requests.get(player_list_url)
             player_list_results_results_json = player_list_results.json()
                    
             jsonpath_expr = parse(f"$.data[?(@.shirtNumber=='{athlete_results_json['jersey']}' & @.team.title == '{team_results_json['displayName']}')]")
             match = [items.value['images']['head_shot']['url'] for items in jsonpath_expr.find(player_list_results_results_json)]
             image_url = f'{base_url}{match[0]}' if len(match) > 0 else 'N/A'
           except:
             image_url = 'N/A'

         # liga mx
         elif league['display'] == 'Liga MX':
           try:
             club_squad_url = f"https://ligamx.net/cancha/club/{getTeamUrl(team_results_json['displayName'])}"
             club_squad_results = requests.get(club_squad_url)
             club_squad_results_parsed = BeautifulSoup(club_squad_results.content.decode('utf-8'))

             match = [number.parent.parent.parent.find('img') for number in club_squad_results_parsed.find_all('strong', {'class': 'numero'}) if number.get_text() == f"#{athlete_results_json['jersey']}"]
             image_url = match[0]['src'] if len(match) > 0 else 'N/A'
           except:
             image_url = 'N/A'

         # ligue 1
         elif league['display'] == 'Ligue 1':
           try:
             base_url = "https://www.ligue1.com"
             club_squad_url = f"{base_url}/clubs/squad?id={getTeamUrl(team_results_json['displayName'])}"
             club_squad_results = requests.get(club_squad_url)
             club_squad_results_parsed = BeautifulSoup(club_squad_results.content.decode('utf-8'))

             match = [number.parent.find('img') for number in club_squad_results_parsed.find_all('div', {'class': 'SquadTeamTable-detail--number'}) if number.get_text(strip=True) == athlete_results_json['jersey']]
             image_url = f"{base_url}{match[0]['src']}" if len(match) > 0 else 'N/A'
           except:
             image_url = 'N/A'

         # serie A
         elif league['display'] == 'Serie A':
           try:
             player_results = requests.get(f"https://www.legaseriea.it/api/team/{getTeamUrl(team_results_json['displayName'])}/players")
             player_results_json = player_results.json()

             jsonpath_expr = parse(f"$..data.*[?(@.uniform_number={athlete_results_json['jersey']})]")
             match = [items.value['medium_shot'] for items in jsonpath_expr.find(player_results_json)]
             image_url = match[0]
           except:
             image_url = 'N/A'
            
         # Grab stats for current player
         cur_name = athlete_results_json['displayName']
         cur_team = team_results_json['displayName']
         cur_league = league['display']
         cur_position = athlete_results_json['position']['displayName']
         cur_jersey_number = athlete_results_json['jersey']if 'jersey' in athlete_results_json else 'N/A'
         cur_goals = getJSONValue(athlete_stats_results_json, 'offensive', 'totalGoals')
         cur_assists = getJSONValue(athlete_stats_results_json, 'offensive', 'goalAssists')
         cur_yellow_cards = getJSONValue(athlete_stats_results_json, 'general', 'yellowCards')
         cur_red_cards = getJSONValue(athlete_stats_results_json, 'general', 'redCards')
         cur_shots = getJSONValue(athlete_stats_results_json, 'offensive', 'totalShots')
         cur_shots_og = getJSONValue(athlete_stats_results_json, 'offensive', 'shotsOnTarget')
         cur_saves = getJSONValue(athlete_stats_results_json, 'goalKeeping', 'saves')
         cur_clean_sheets = getJSONValue(athlete_stats_results_json, 'goalKeeping', 'cleanSheet')
         cur_goals_against = getJSONValue(athlete_stats_results_json, 'goalKeeping', 'goalsConceded')
         cur_photo_url = image_url
         cur_height = athlete_results_json['displayHeight'] if 'displayHeight' in athlete_results_json else 'N/A'
         cur_weight = athlete_results_json['displayWeight'] if 'displayWeight' in athlete_results_json else 'N/A'
         cur_birthdate = athlete_results_json['dateOfBirth']if 'dateOfBirth' in athlete_results_json else 'N/A'
         cur_nationality = athlete_results_json['citizenship']if 'citizenship' in athlete_results_json else 'N/A'
            
         # Print summary
         print('**********')
         print(f"Name: {cur_name}")
         print(f"Team: {cur_team}")
         print(f"League: {cur_league}")
         print(f"Position: {cur_position}")
         print(f"Jersey Number: {cur_jersey_number}")
         print(f"Goals: {cur_goals}")
         print(f"Assists: {cur_assists}")
         print(f"Yellow Cards: {cur_yellow_cards}")
         print(f"Red Cards: {cur_red_cards}")
         print(f"Shots: {cur_shots}")
         print(f"Shots on Goal: {cur_shots_og}")
         print(f"Saves: {cur_saves}")
         print(f"Clean Sheets: {cur_clean_sheets}")
         print(f"Goals Against: {cur_goals_against}")
         print(f"Image URL: {cur_photo_url}")
         print(f"Height: {cur_height}")
         print(f"Weight: {cur_weight}")
         print(f"Birthdate: {cur_birthdate}")
         print(f"Nationality: {cur_nationality}")

         # Append those stats to their respective lists
         names.append(cur_name)
         teams.append(cur_team)
         leagues.append(cur_league)
         positions.append(cur_position)
         jersey_numbers.append(cur_jersey_number)
         goals.append(cur_goals)
         assists.append(cur_assists)
         yellow_cards.append(cur_yellow_cards)
         red_cards.append(cur_red_cards)
         shots.append(cur_shots)
         shots_og.append(cur_shots_og)
         saves.append(cur_saves)
         clean_sheets.append(cur_clean_sheets)
         goals_against.append(cur_goals_against)
         photo_urls.append(cur_photo_url)
         heights.append(cur_height)
         weights.append(cur_weight)
         birthdates.append(cur_birthdate)
         nationalities.append(cur_nationality)
# Out:
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/5289?lang=en&region=us
# **********
# Name: Patrick Agyemang
# Team: Charlotte FC
# League: MLS
# Position: Forward
# Jersey Number: 33
# Goals: 2
# Assists: 0
# Yellow Cards: 3
# Red Cards: 0
# Shots: 8
# Shots on Goal: 3
# Saves: 0
# Clean Sheets: 0
# Goals Against: 6
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/5289.png
# Height: 6' 4"
# Weight: 196 lbs
# Birthdate: 2000-11-07T08:00Z
# Nationality: Ghana
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/6746?lang=en&region=us
# **********
# Name: David Bingham
# Team: Portland Timbers
# League: MLS
# Position: Goalkeeper
# Jersey Number: 1
# Goals: 0
# Assists: 0
# Yellow Cards: 2
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 49
# Clean Sheets: 6
# Goals Against: 29
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/6746.png
# Height: 6' 2"
# Weight: 183 lbs
# Birthdate: 1989-10-19T07:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/7567?lang=en&region=us
# **********
# Name: Ashley Westwood
# Team: Charlotte FC
# League: MLS
# Position: Midfielder
# Jersey Number: 8
# Goals: 3
# Assists: 4
# Yellow Cards: 6
# Red Cards: 0
# Shots: 18
# Shots on Goal: 3
# Saves: 6
# Clean Sheets: 6
# Goals Against: 45
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/7567.png
# Height: 5' 9"
# Weight: 174 lbs
# Birthdate: 1990-04-01T08:00Z
# Nationality: England
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/8894?lang=en&region=us
# **********
# Name: Sean Davis
# Team: Nashville SC
# League: MLS
# Position: Midfielder
# Jersey Number: 54
# Goals: 0
# Assists: 1
# Yellow Cards: 0
# Red Cards: 0
# Shots: 11
# Shots on Goal: 1
# Saves: 18
# Clean Sheets: 8
# Goals Against: 21
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/8894.png
# Height: 6' 0"
# Weight: 163 lbs
# Birthdate: 1993-02-08T08:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/16151?lang=en&region=us
# **********
# Name: Steve Clark
# Team: Houston Dynamo FC
# League: MLS
# Position: Goalkeeper
# Jersey Number: 12
# Goals: 0
# Assists: 2
# Yellow Cards: 5
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 90
# Clean Sheets: 13
# Goals Against: 40
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/16151.png
# Height: 6' 2"
# Weight: 190 lbs
# Birthdate: 1986-04-14T08:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/16700?lang=en&region=us
# **********
# Name: Cameron Johnson
# Team: Inter Miami CF
# League: MLS
# Position: Forward
# Jersey Number: 89
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: N/A
# Height: N/A
# Weight: N/A
# Birthdate: 2004-04-16T07:00Z
# Nationality: Costa Rica
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/17478?lang=en&region=us
# **********
# Name: Michael Halliday
# Team: Orlando City SC
# League: MLS
# Position: Defender
# Jersey Number: 26
# Goals: 0
# Assists: 2
# Yellow Cards: 2
# Red Cards: 0
# Shots: 4
# Shots on Goal: 0
# Saves: 3
# Clean Sheets: 3
# Goals Against: 7
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/17478.png
# Height: 6' 1"
# Weight: 157 lbs
# Birthdate: 2003-01-22T08:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/23761?lang=en&region=us
# **********
# Name: Antonio Leone
# Team: LAFC
# League: MLS
# Position: Midfielder
# Jersey Number: 28
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/23761.png
# Height: 6' 1"
# Weight: 181 lbs
# Birthdate: 2004-04-28T07:00Z
# Nationality: Mexico
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/24836?lang=en&region=us
# **********
# Name: Giorgio Chiellini
# Team: LAFC
# League: MLS
# Position: Defender
# Jersey Number: 14
# Goals: 1
# Assists: 2
# Yellow Cards: 2
# Red Cards: 0
# Shots: 9
# Shots on Goal: 2
# Saves: 8
# Clean Sheets: 5
# Goals Against: 15
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/24836.png
# Height: 6' 2"
# Weight: 185 lbs
# Birthdate: 1984-08-14T07:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/26703?lang=en&region=us
# **********
# Name: David Rodriguez
# Team: Austin FC
# League: MLS
# Position: Midfielder
# Jersey Number: 32
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: N/A
# Height: 5' 7"
# Weight: 139 lbs
# Birthdate: 2002-05-05T07:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/41952?lang=en&region=us
# **********
# Name: Michael Bradley
# Team: Toronto FC
# League: MLS
# Position: Midfielder
# Jersey Number: 4
# Goals: 1
# Assists: 1
# Yellow Cards: 2
# Red Cards: 0
# Shots: 6
# Shots on Goal: 4
# Saves: 4
# Clean Sheets: 3
# Goals Against: 31
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/41952.png
# Height: 6' 1"
# Weight: 192 lbs
# Birthdate: 1987-07-31T07:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/45702?lang=en&region=us
# **********
# Name: Stephen Turnbull
# Team: New York City FC
# League: MLS
# Position: Defender
# Jersey Number: 34
# Goals: 0
# Assists: 1
# Yellow Cards: 1
# Red Cards: 0
# Shots: 1
# Shots on Goal: 0
# Saves: 3
# Clean Sheets: 1
# Goals Against: 6
# Image URL: N/A
# Height: 5' 11"
# Weight: 154 lbs
# Birthdate: 1998-03-13T08:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/45843?lang=en&region=us
# **********
# Name: Lionel Messi
# Team: Inter Miami CF
# League: MLS
# Position: Forward
# Jersey Number: 10
# Goals: 1
# Assists: 2
# Yellow Cards: 0
# Red Cards: 0
# Shots: 19
# Shots on Goal: 5
# Saves: 0
# Clean Sheets: 1
# Goals Against: 3
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/45843.png
# Height: 5' 7"
# Weight: 159 lbs
# Birthdate: 1987-06-24T07:00Z
# Nationality: Argentina
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/48484?lang=en&region=us
# **********
# Name: Luis Amarilla
# Team: Minnesota United FC
# League: MLS
# Position: Forward
# Jersey Number: 9
# Goals: 2
# Assists: 0
# Yellow Cards: 2
# Red Cards: 0
# Shots: 22
# Shots on Goal: 8
# Saves: 0
# Clean Sheets: 3
# Goals Against: 9
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/48484.png
# Height: 6' 0"
# Weight: 161 lbs
# Birthdate: 1995-08-25T07:00Z
# Nationality: Paraguay
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/56935?lang=en&region=us
# **********
# Name: Brad Guzan
# Team: Atlanta United FC
# League: MLS
# Position: Goalkeeper
# Jersey Number: 1
# Goals: 0
# Assists: 0
# Yellow Cards: 2
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 73
# Clean Sheets: 7
# Goals Against: 47
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/56935.png
# Height: 6' 4"
# Weight: 205 lbs
# Birthdate: 1984-09-09T07:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/65434?lang=en&region=us
# **********
# Name: Jonathan Bond
# Team: LA Galaxy
# League: MLS
# Position: Goalkeeper
# Jersey Number: 1
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 80
# Clean Sheets: 4
# Goals Against: 44
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/65434.png
# Height: 6' 5"
# Weight: 185 lbs
# Birthdate: 1993-05-19T07:00Z
# Nationality: England
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/66579?lang=en&region=us
# **********
# Name: Michael Edwards
# Team: Colorado Rapids
# League: MLS
# Position: Defender
# Jersey Number: 34
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/66579.png
# Height: 6' 4"
# Weight: 174 lbs
# Birthdate: 2000-11-27T08:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/67518?lang=en&region=us
# **********
# Name: Facundo Torres
# Team: Orlando City SC
# League: MLS
# Position: Midfielder
# Jersey Number: 17
# Goals: 14
# Assists: 6
# Yellow Cards: 2
# Red Cards: 0
# Shots: 71
# Shots on Goal: 27
# Saves: 0
# Clean Sheets: 9
# Goals Against: 24
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/67518.png
# Height: 5' 10"
# Weight: 157 lbs
# Birthdate: 2000-04-13T07:00Z
# Nationality: Uruguay
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/67671?lang=en&region=us
# **********
# Name: Joakim Nilsson
# Team: St. Louis CITY SC
# League: MLS
# Position: Defender
# Jersey Number: 4
# Goals: 0
# Assists: 0
# Yellow Cards: 1
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 11
# Clean Sheets: 1
# Goals Against: 13
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/67671.png
# Height: 6' 1"
# Weight: 172 lbs
# Birthdate: 1994-02-06T08:00Z
# Nationality: Sweden
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/69318?lang=en&region=us
# **********
# Name: Eldin Jakupovic
# Team: LAFC
# League: MLS
# Position: Goalkeeper
# Jersey Number: 1
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 6
# Clean Sheets: 1
# Goals Against: 1
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/69318.png
# Height: 6' 3"
# Weight: 185 lbs
# Birthdate: 1984-10-02T07:00Z
# Nationality: Switzerland
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/70624?lang=en&region=us
# **********
# Name: Maxi Morález
# Team: New York City FC
# League: MLS
# Position: Midfielder
# Jersey Number: 27
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 6
# Shots on Goal: 1
# Saves: 1
# Clean Sheets: 0
# Goals Against: 6
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/70624.png
# Height: 5' 3"
# Weight: 115 lbs
# Birthdate: 1987-02-27T08:00Z
# Nationality: Argentina
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/70745?lang=en&region=us
# **********
# Name: Fredy Montero
# Team: Seattle Sounders FC
# League: MLS
# Position: Forward
# Jersey Number: 12
# Goals: 1
# Assists: 1
# Yellow Cards: 0
# Red Cards: 0
# Shots: 16
# Shots on Goal: 4
# Saves: 0
# Clean Sheets: 0
# Goals Against: 3
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/70745.png
# Height: 5' 9"
# Weight: 161 lbs
# Birthdate: 1987-07-26T07:00Z
# Nationality: Colombia
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/71042?lang=en&region=us
# **********
# Name: Diego Chará
# Team: Portland Timbers
# League: MLS
# Position: Midfielder
# Jersey Number: 21
# Goals: 0
# Assists: 4
# Yellow Cards: 8
# Red Cards: 0
# Shots: 3
# Shots on Goal: 1
# Saves: 9
# Clean Sheets: 9
# Goals Against: 41
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/71042.png
# Height: 5' 8"
# Weight: 150 lbs
# Birthdate: 1986-04-05T08:00Z
# Nationality: Colombia
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/71067?lang=en&region=us
# **********
# Name: Mario González
# Team: LAFC
# League: MLS
# Position: Goalkeeper
# Jersey Number: 9
# Goals: 1
# Assists: 1
# Yellow Cards: 1
# Red Cards: 0
# Shots: 8
# Shots on Goal: 4
# Saves: 0
# Clean Sheets: 0
# Goals Against: 6
# Image URL: N/A
# Height: 5' 9"
# Weight: 150 lbs
# Birthdate: 1997-05-20T07:00Z
# Nationality: El Salvador
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/72478?lang=en&region=us
# **********
# Name: Sean Rea
# Team: CF Montréal
# League: MLS
# Position: Midfielder
# Jersey Number: 27
# Goals: 0
# Assists: 2
# Yellow Cards: 2
# Red Cards: 0
# Shots: 4
# Shots on Goal: 1
# Saves: 0
# Clean Sheets: 0
# Goals Against: 14
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/72478.png
# Height: 5' 7"
# Weight: 130 lbs
# Birthdate: 2002-05-15T07:00Z
# Nationality: Canada
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/73200?lang=en&region=us
# **********
# Name: Cristian Espinoza
# Team: San Jose Earthquakes
# League: MLS
# Position: Midfielder
# Jersey Number: 10
# Goals: 13
# Assists: 13
# Yellow Cards: 6
# Red Cards: 0
# Shots: 67
# Shots on Goal: 27
# Saves: 3
# Clean Sheets: 11
# Goals Against: 41
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/73200.png
# Height: 5' 9"
# Weight: 161 lbs
# Birthdate: 1995-04-03T07:00Z
# Nationality: Argentina
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/75574?lang=en&region=us
# **********
# Name: Kei Kamara
# Team: Chicago Fire FC
# League: MLS
# Position: Forward
# Jersey Number: 23
# Goals: 5
# Assists: 2
# Yellow Cards: 2
# Red Cards: 1
# Shots: 53
# Shots on Goal: 22
# Saves: 4
# Clean Sheets: 2
# Goals Against: 23
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/75574.png
# Height: 6' 3"
# Weight: 185 lbs
# Birthdate: 1984-09-01T07:00Z
# Nationality: Sierra Leone
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/75577?lang=en&region=us
# **********
# Name: Dax McCarty
# Team: Nashville SC
# League: MLS
# Position: Midfielder
# Jersey Number: 6
# Goals: 1
# Assists: 3
# Yellow Cards: 7
# Red Cards: 0
# Shots: 10
# Shots on Goal: 1
# Saves: 12
# Clean Sheets: 4
# Goals Against: 16
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/75577.png
# Height: 5' 9"
# Weight: 150 lbs
# Birthdate: 1987-04-30T07:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/75703?lang=en&region=us
# **********
# Name: Luis Caicedo
# Team: Houston Dynamo FC
# League: MLS
# Position: Midfielder
# Jersey Number: 27
# Goals: 0
# Assists: 0
# Yellow Cards: 6
# Red Cards: 0
# Shots: 3
# Shots on Goal: 0
# Saves: 6
# Clean Sheets: 5
# Goals Against: 13
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/75703.png
# Height: 5' 8"
# Weight: 148 lbs
# Birthdate: 1996-05-18T07:00Z
# Nationality: Colombia
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/76098?lang=en&region=us
# **********
# Name: Carlos Vela
# Team: LAFC
# League: MLS
# Position: Forward
# Jersey Number: 10
# Goals: 9
# Assists: 13
# Yellow Cards: 1
# Red Cards: 0
# Shots: 61
# Shots on Goal: 25
# Saves: 0
# Clean Sheets: 1
# Goals Against: 30
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/76098.png
# Height: 5' 10"
# Weight: 170 lbs
# Birthdate: 1989-03-01T08:00Z
# Nationality: Mexico
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/76914?lang=en&region=us
# **********
# Name: Sebastián Blanco
# Team: Portland Timbers
# League: MLS
# Position: Forward
# Jersey Number: 10
# Goals: 1
# Assists: 1
# Yellow Cards: 2
# Red Cards: 0
# Shots: 6
# Shots on Goal: 1
# Saves: 0
# Clean Sheets: 0
# Goals Against: 10
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/76914.png
# Height: 5' 7"
# Weight: 150 lbs
# Birthdate: 1988-03-15T08:00Z
# Nationality: Argentina
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/82716?lang=en&region=us
# **********
# Name: Nelson Palacio
# Team: Real Salt Lake
# League: MLS
# Position: Midfielder
# Jersey Number: 13
# Goals: 0
# Assists: 1
# Yellow Cards: 3
# Red Cards: 0
# Shots: 8
# Shots on Goal: 3
# Saves: 2
# Clean Sheets: 2
# Goals Against: 20
# Image URL: N/A
# Height: 5' 11"
# Weight: 174 lbs
# Birthdate: 2001-06-16T07:00Z
# Nationality: Colombia
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/83178?lang=en&region=us
# **********
# Name: Santiago Rodríguez
# Team: New York City FC
# League: MLS
# Position: Midfielder
# Jersey Number: 10
# Goals: 5
# Assists: 8
# Yellow Cards: 9
# Red Cards: 0
# Shots: 45
# Shots on Goal: 14
# Saves: 2
# Clean Sheets: 8
# Goals Against: 30
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/83178.png
# Height: 5' 6"
# Weight: 137 lbs
# Birthdate: 2000-01-08T08:00Z
# Nationality: Uruguay
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/84036?lang=en&region=us
# **********
# Name: Scott Arfield
# Team: Charlotte FC
# League: MLS
# Position: Midfielder
# Jersey Number: 37
# Goals: 2
# Assists: 0
# Yellow Cards: 1
# Red Cards: 0
# Shots: 9
# Shots on Goal: 2
# Saves: 1
# Clean Sheets: 0
# Goals Against: 11
# Image URL: N/A
# Height: 5' 10"
# Weight: 152 lbs
# Birthdate: 1988-11-01T08:00Z
# Nationality: Canada
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/85074?lang=en&region=us
# **********
# Name: Quentin Westberg
# Team: Atlanta United FC
# League: MLS
# Position: Goalkeeper
# Jersey Number: 31
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 10
# Clean Sheets: 1
# Goals Against: 9
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/85074.png
# Height: 6' 1"
# Weight: 168 lbs
# Birthdate: 1986-04-25T08:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/86436?lang=en&region=us
# **********
# Name: Evander
# Team: Portland Timbers
# League: MLS
# Position: Midfielder
# Jersey Number: 20
# Goals: 9
# Assists: 5
# Yellow Cards: 5
# Red Cards: 0
# Shots: 73
# Shots on Goal: 24
# Saves: 2
# Clean Sheets: 7
# Goals Against: 36
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/86436.png
# Height: 5' 10"
# Weight: 168 lbs
# Birthdate: 1998-06-09T07:00Z
# Nationality: Brazil
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/87387?lang=en&region=us
# **********
# Name: Samuel Piette
# Team: CF Montréal
# League: MLS
# Position: Midfielder
# Jersey Number: 6
# Goals: 0
# Assists: 0
# Yellow Cards: 3
# Red Cards: 0
# Shots: 2
# Shots on Goal: 0
# Saves: 4
# Clean Sheets: 2
# Goals Against: 19
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/87387.png
# Height: 5' 7"
# Weight: 161 lbs
# Birthdate: 1994-11-12T08:00Z
# Nationality: Canada
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/88374?lang=en&region=us
# **********
# Name: Marcelo Silva
# Team: Real Salt Lake
# League: MLS
# Position: Defender
# Jersey Number: 30
# Goals: 0
# Assists: 0
# Yellow Cards: 2
# Red Cards: 0
# Shots: 11
# Shots on Goal: 1
# Saves: 12
# Clean Sheets: 3
# Goals Against: 26
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/88374.png
# Height: 6' 1"
# Weight: 201 lbs
# Birthdate: 1989-03-21T08:00Z
# Nationality: Uruguay
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/89175?lang=en&region=us
# **********
# Name: Adrian Gonzalez
# Team: LA Galaxy
# League: MLS
# Position: Midfielder
# Jersey Number: 45
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: N/A
# Height: 5' 6"
# Weight: 139 lbs
# Birthdate: 2003-06-23T07:00Z
# Nationality: Mexico
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/96526?lang=en&region=us
# **********
# Name: Jonathan Pérez
# Team: LA Galaxy
# League: MLS
# Position: Midfielder
# Jersey Number: 56
# Goals: 0
# Assists: 1
# Yellow Cards: 1
# Red Cards: 0
# Shots: 5
# Shots on Goal: 1
# Saves: 0
# Clean Sheets: 0
# Goals Against: 2
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/96526.png
# Height: 5' 6"
# Weight: 159 lbs
# Birthdate: 2003-01-18T08:00Z
# Nationality: Mexico
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/98448?lang=en&region=us
# **********
# Name: Larrys Mabiala
# Team: Portland Timbers
# League: MLS
# Position: Defender
# Jersey Number: 33
# Goals: 1
# Assists: 0
# Yellow Cards: 3
# Red Cards: 0
# Shots: 8
# Shots on Goal: 2
# Saves: 8
# Clean Sheets: 1
# Goals Against: 22
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/98448.png
# Height: 6' 2"
# Weight: 183 lbs
# Birthdate: 1987-10-08T07:00Z
# Nationality: Congo DR
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/100525?lang=en&region=us
# **********
# Name: Johnny Russell
# Team: Sporting Kansas City
# League: MLS
# Position: Forward
# Jersey Number: 7
# Goals: 8
# Assists: 4
# Yellow Cards: 1
# Red Cards: 1
# Shots: 45
# Shots on Goal: 17
# Saves: 3
# Clean Sheets: 4
# Goals Against: 28
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/100525.png
# Height: 5' 10"
# Weight: 172 lbs
# Birthdate: 1990-04-08T07:00Z
# Nationality: Scotland
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/100802?lang=en&region=us
# **********
# Name: Osvaldo Alonso
# Team: Atlanta United FC
# League: MLS
# Position: Midfielder
# Jersey Number: 6
# Goals: 0
# Assists: 0
# Yellow Cards: 1
# Red Cards: 0
# Shots: 2
# Shots on Goal: 0
# Saves: 3
# Clean Sheets: 0
# Goals Against: 1
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/100802.png
# Height: 5' 11"
# Weight: 157 lbs
# Birthdate: 1985-11-11T08:00Z
# Nationality: Cuba
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/101934?lang=en&region=us
# **********
# Name: Michael Boxall
# Team: Minnesota United FC
# League: MLS
# Position: Defender
# Jersey Number: 15
# Goals: 2
# Assists: 0
# Yellow Cards: 9
# Red Cards: 0
# Shots: 14
# Shots on Goal: 3
# Saves: 31
# Clean Sheets: 8
# Goals Against: 44
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/101934.png
# Height: 6' 2"
# Weight: 201 lbs
# Birthdate: 1988-08-18T07:00Z
# Nationality: New Zealand
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/103029?lang=en&region=us
# **********
# Name: Martín Cáceres
# Team: LA Galaxy
# League: MLS
# Position: Defender
# Jersey Number: 22
# Goals: 2
# Assists: 0
# Yellow Cards: 2
# Red Cards: 1
# Shots: 5
# Shots on Goal: 2
# Saves: 9
# Clean Sheets: 3
# Goals Against: 23
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/103029.png
# Height: 5' 11"
# Weight: 170 lbs
# Birthdate: 1987-04-07T07:00Z
# Nationality: Uruguay
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/105803?lang=en&region=us
# **********
# Name: Maya Yoshida
# Team: LA Galaxy
# League: MLS
# Position: Defender
# Jersey Number: 4
# Goals: 1
# Assists: 3
# Yellow Cards: 3
# Red Cards: 0
# Shots: 9
# Shots on Goal: 3
# Saves: 11
# Clean Sheets: 2
# Goals Against: 28
# Image URL: N/A
# Height: 6' 2"
# Weight: 172 lbs
# Birthdate: 1988-08-24T07:00Z
# Nationality: Japan
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/105957?lang=en&region=us
# **********
# Name: Nicolás Lodeiro
# Team: Seattle Sounders FC
# League: MLS
# Position: Midfielder
# Jersey Number: 10
# Goals: 1
# Assists: 11
# Yellow Cards: 6
# Red Cards: 0
# Shots: 47
# Shots on Goal: 11
# Saves: 1
# Clean Sheets: 12
# Goals Against: 25
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/105957.png
# Height: 5' 9"
# Weight: 157 lbs
# Birthdate: 1989-03-21T08:00Z
# Nationality: Uruguay
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/106957?lang=en&region=us
# **********
# Name: Christian Benteke
# Team: D.C. United
# League: MLS
# Position: Forward
# Jersey Number: 20
# Goals: 14
# Assists: 4
# Yellow Cards: 8
# Red Cards: 0
# Shots: 104
# Shots on Goal: 35
# Saves: 3
# Clean Sheets: 9
# Goals Against: 47
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/106957.png
# Height: 6' 3"
# Weight: 183 lbs
# Birthdate: 1990-12-03T08:00Z
# Nationality: Belgium
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/115989?lang=en&region=us
# **********
# Name: Víctor Vázquez
# Team: Toronto FC
# League: MLS
# Position: Midfielder
# Jersey Number: 8
# Goals: 0
# Assists: 0
# Yellow Cards: 1
# Red Cards: 0
# Shots: 2
# Shots on Goal: 0
# Saves: 1
# Clean Sheets: 0
# Goals Against: 4
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/115989.png
# Height: 5' 11"
# Weight: 172 lbs
# Birthdate: 1987-01-20T08:00Z
# Nationality: Spain
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/116662?lang=en&region=us
# **********
# Name: Junior Hoilett
# Team: Vancouver Whitecaps
# League: MLS
# Position: Forward
# Jersey Number: 11
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 6
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 5
# Image URL: N/A
# Height: 5' 9"
# Weight: 152 lbs
# Birthdate: 1990-06-05T07:00Z
# Nationality: Canada
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/116825?lang=en&region=us
# **********
# Name: Aníbal Godoy
# Team: Nashville SC
# League: MLS
# Position: Midfielder
# Jersey Number: 20
# Goals: 0
# Assists: 1
# Yellow Cards: 7
# Red Cards: 0
# Shots: 7
# Shots on Goal: 3
# Saves: 6
# Clean Sheets: 4
# Goals Against: 18
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/116825.png
# Height: 6' 0"
# Weight: 163 lbs
# Birthdate: 1990-02-10T08:00Z
# Nationality: Panama
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/117713?lang=en&region=us
# **********
# Name: Roger Espinoza
# Team: Sporting Kansas City
# League: MLS
# Position: Midfielder
# Jersey Number: 15
# Goals: 0
# Assists: 2
# Yellow Cards: 4
# Red Cards: 0
# Shots: 15
# Shots on Goal: 5
# Saves: 1
# Clean Sheets: 0
# Goals Against: 9
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/117713.png
# Height: 5' 11"
# Weight: 183 lbs
# Birthdate: 1986-10-25T07:00Z
# Nationality: Honduras
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/117830?lang=en&region=us
# **********
# Name: Gustavo Bou
# Team: New England Revolution
# League: MLS
# Position: Forward
# Jersey Number: 7
# Goals: 8
# Assists: 4
# Yellow Cards: 0
# Red Cards: 0
# Shots: 61
# Shots on Goal: 23
# Saves: 1
# Clean Sheets: 4
# Goals Against: 19
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/117830.png
# Height: 5' 9"
# Weight: 159 lbs
# Birthdate: 1990-02-18T08:00Z
# Nationality: Argentina
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/121021?lang=en&region=us
# **********
# Name: Jordi Alba
# Team: Inter Miami CF
# League: MLS
# Position: Defender
# Jersey Number: 18
# Goals: 1
# Assists: 0
# Yellow Cards: 2
# Red Cards: 0
# Shots: 1
# Shots on Goal: 1
# Saves: 0
# Clean Sheets: 3
# Goals Against: 2
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/121021.png
# Height: 5' 7"
# Weight: 150 lbs
# Birthdate: 1989-03-21T08:00Z
# Nationality: Spain
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/121714?lang=en&region=us
# **********
# Name: Victor Ulloa
# Team: Inter Miami CF
# League: MLS
# Position: Midfielder
# Jersey Number: 13
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 1
# Clean Sheets: 0
# Goals Against: 6
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/121714.png
# Height: 5' 11"
# Weight: 163 lbs
# Birthdate: 1992-03-04T08:00Z
# Nationality: Mexico
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/121893?lang=en&region=us
# **********
# Name: Sergio Busquets
# Team: Inter Miami CF
# League: MLS
# Position: Midfielder
# Jersey Number: 5
# Goals: 0
# Assists: 2
# Yellow Cards: 3
# Red Cards: 0
# Shots: 1
# Shots on Goal: 0
# Saves: 2
# Clean Sheets: 2
# Goals Against: 16
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/121893.png
# Height: 6' 2"
# Weight: 168 lbs
# Birthdate: 1988-07-16T07:00Z
# Nationality: Spain
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/124439?lang=en&region=us
# **********
# Name: Cristian Olivera
# Team: LAFC
# League: MLS
# Position: Midfielder
# Jersey Number: 25
# Goals: 2
# Assists: 0
# Yellow Cards: 2
# Red Cards: 0
# Shots: 29
# Shots on Goal: 13
# Saves: 1
# Clean Sheets: 2
# Goals Against: 8
# Image URL: N/A
# Height: 5' 9"
# Weight: 170 lbs
# Birthdate: 2002-04-17T07:00Z
# Nationality: Uruguay
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/126619?lang=en&region=us
# **********
# Name: Felipe
# Team: Orlando City SC
# League: MLS
# Position: Midfielder
# Jersey Number: 8
# Goals: 0
# Assists: 1
# Yellow Cards: 3
# Red Cards: 0
# Shots: 9
# Shots on Goal: 3
# Saves: 2
# Clean Sheets: 0
# Goals Against: 10
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/126619.png
# Height: 5' 9"
# Weight: 152 lbs
# Birthdate: 1990-09-30T07:00Z
# Nationality: Brazil
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/127520?lang=en&region=us
# **********
# Name: Teemu Pukki
# Team: Minnesota United FC
# League: MLS
# Position: Forward
# Jersey Number: 22
# Goals: 10
# Assists: 1
# Yellow Cards: 0
# Red Cards: 0
# Shots: 38
# Shots on Goal: 19
# Saves: 0
# Clean Sheets: 2
# Goals Against: 18
# Image URL: N/A
# Height: 5' 11"
# Weight: 163 lbs
# Birthdate: 1990-03-29T08:00Z
# Nationality: Finland
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/130467?lang=en&region=us
# **********
# Name: Danny Wilson
# Team: Colorado Rapids
# League: MLS
# Position: Defender
# Jersey Number: 4
# Goals: 1
# Assists: 1
# Yellow Cards: 5
# Red Cards: 0
# Shots: 12
# Shots on Goal: 4
# Saves: 28
# Clean Sheets: 6
# Goals Against: 41
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/130467.png
# Height: 6' 2"
# Weight: 172 lbs
# Birthdate: 1991-12-27T08:00Z
# Nationality: Scotland
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/131466?lang=en&region=us
# **********
# Name: Chris Mavinga
# Team: LA Galaxy
# League: MLS
# Position: Defender
# Jersey Number: 17
# Goals: 0
# Assists: 0
# Yellow Cards: 2
# Red Cards: 1
# Shots: 5
# Shots on Goal: 1
# Saves: 11
# Clean Sheets: 2
# Goals Against: 26
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/131466.png
# Height: 6' 0"
# Weight: 179 lbs
# Birthdate: 1991-05-26T07:00Z
# Nationality: France
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/131979?lang=en&region=us
# **********
# Name: Stefan Frei
# Team: Seattle Sounders FC
# League: MLS
# Position: Goalkeeper
# Jersey Number: 24
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 1
# Shots on Goal: 1
# Saves: 82
# Clean Sheets: 17
# Goals Against: 29
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/131979.png
# Height: 6' 3"
# Weight: 194 lbs
# Birthdate: 1986-04-20T08:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/132237?lang=en&region=us
# **********
# Name: Omar González
# Team: New England Revolution
# League: MLS
# Position: Defender
# Jersey Number: 3
# Goals: 1
# Assists: 0
# Yellow Cards: 3
# Red Cards: 0
# Shots: 2
# Shots on Goal: 1
# Saves: 13
# Clean Sheets: 1
# Goals Against: 19
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/132237.png
# Height: 6' 5"
# Weight: 205 lbs
# Birthdate: 1988-10-11T07:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/132374?lang=en&region=us
# **********
# Name: Graham Zusi
# Team: Sporting Kansas City
# League: MLS
# Position: Defender
# Jersey Number: 8
# Goals: 0
# Assists: 1
# Yellow Cards: 0
# Red Cards: 0
# Shots: 9
# Shots on Goal: 2
# Saves: 4
# Clean Sheets: 3
# Goals Against: 14
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/132374.png
# Height: 5' 10"
# Weight: 159 lbs
# Birthdate: 1986-08-18T07:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/133111?lang=en&region=us
# **********
# Name: Daniel Aguirre
# Team: LA Galaxy
# League: MLS
# Position: Midfielder
# Jersey Number: 37
# Goals: 1
# Assists: 1
# Yellow Cards: 3
# Red Cards: 0
# Shots: 15
# Shots on Goal: 6
# Saves: 2
# Clean Sheets: 0
# Goals Against: 13
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/133111.png
# Height: 5' 7"
# Weight: 163 lbs
# Birthdate: 1999-07-28T07:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/134066?lang=en&region=us
# **********
# Name: Alejandro Bedoya
# Team: Philadelphia Union
# League: MLS
# Position: Midfielder
# Jersey Number: 11
# Goals: 0
# Assists: 7
# Yellow Cards: 6
# Red Cards: 0
# Shots: 26
# Shots on Goal: 9
# Saves: 8
# Clean Sheets: 6
# Goals Against: 26
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/134066.png
# Height: 5' 11"
# Weight: 161 lbs
# Birthdate: 1987-04-29T07:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/135294?lang=en&region=us
# **********
# Name: Andreu Fontàs
# Team: Sporting Kansas City
# League: MLS
# Position: Defender
# Jersey Number: 3
# Goals: 0
# Assists: 1
# Yellow Cards: 5
# Red Cards: 1
# Shots: 13
# Shots on Goal: 1
# Saves: 24
# Clean Sheets: 7
# Goals Against: 42
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/135294.png
# Height: 6' 2"
# Weight: 201 lbs
# Birthdate: 1989-11-14T08:00Z
# Nationality: Spain
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/136135?lang=en&region=us
# **********
# Name: Alan Pulido
# Team: Sporting Kansas City
# League: MLS
# Position: Forward
# Jersey Number: 9
# Goals: 14
# Assists: 6
# Yellow Cards: 3
# Red Cards: 0
# Shots: 57
# Shots on Goal: 27
# Saves: 4
# Clean Sheets: 5
# Goals Against: 36
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/136135.png
# Height: 5' 10"
# Weight: 181 lbs
# Birthdate: 1991-03-08T08:00Z
# Nationality: Mexico
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/136638?lang=en&region=us
# **********
# Name: Jonathan Mensah
# Team: San Jose Earthquakes
# League: MLS
# Position: Defender
# Jersey Number: 4
# Goals: 0
# Assists: 0
# Yellow Cards: 3
# Red Cards: 0
# Shots: 17
# Shots on Goal: 3
# Saves: 20
# Clean Sheets: 5
# Goals Against: 29
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/136638.png
# Height: 6' 2"
# Weight: 183 lbs
# Birthdate: 1990-07-13T07:00Z
# Nationality: Ghana
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/136775?lang=en&region=us
# **********
# Name: Xherdan Shaqiri
# Team: Chicago Fire FC
# League: MLS
# Position: Midfielder
# Jersey Number: 10
# Goals: 5
# Assists: 5
# Yellow Cards: 3
# Red Cards: 1
# Shots: 35
# Shots on Goal: 11
# Saves: 2
# Clean Sheets: 6
# Goals Against: 34
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/136775.png
# Height: 5' 7"
# Weight: 159 lbs
# Birthdate: 1991-10-10T07:00Z
# Nationality: Switzerland
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/138183?lang=en&region=us
# **********
# Name: Eric Davis
# Team: D.C. United
# League: MLS
# Position: Defender
# Jersey Number: 31
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 3
# Shots on Goal: 0
# Saves: 2
# Clean Sheets: 2
# Goals Against: 9
# Image URL: N/A
# Height: 5' 11"
# Weight: 172 lbs
# Birthdate: 1991-03-31T08:00Z
# Nationality: Panama
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/139028?lang=en&region=us
# **********
# Name: Lorenzo Insigne
# Team: Toronto FC
# League: MLS
# Position: Forward
# Jersey Number: 24
# Goals: 4
# Assists: 5
# Yellow Cards: 2
# Red Cards: 0
# Shots: 64
# Shots on Goal: 21
# Saves: 0
# Clean Sheets: 3
# Goals Against: 27
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/139028.png
# Height: 5' 4"
# Weight: 128 lbs
# Birthdate: 1991-06-04T07:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/139703?lang=en&region=us
# **********
# Name: Victor Wanyama
# Team: CF Montréal
# League: MLS
# Position: Midfielder
# Jersey Number: 2
# Goals: 0
# Assists: 1
# Yellow Cards: 6
# Red Cards: 0
# Shots: 11
# Shots on Goal: 3
# Saves: 2
# Clean Sheets: 8
# Goals Against: 27
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/139703.png
# Height: 6' 2"
# Weight: 174 lbs
# Birthdate: 1991-06-25T07:00Z
# Nationality: KenyaBrazil
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/140468?lang=en&region=us
# **********
# Name: Mauricio Pereyra
# Team: Orlando City SC
# League: MLS
# Position: Midfielder
# Jersey Number: 10
# Goals: 0
# Assists: 12
# Yellow Cards: 4
# Red Cards: 0
# Shots: 18
# Shots on Goal: 4
# Saves: 2
# Clean Sheets: 2
# Goals Against: 29
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/140468.png
# Height: 5' 7"
# Weight: 139 lbs
# Birthdate: 1990-03-15T08:00Z
# Nationality: Uruguay
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/141243?lang=en&region=us
# **********
# Name: Kevin Molino
# Team: Columbus Crew
# League: MLS
# Position: Forward
# Jersey Number: 13
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 1
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 3
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/141243.png
# Height: 5' 11"
# Weight: 174 lbs
# Birthdate: 1990-06-17T07:00Z
# Nationality: Trinidad and Tobago
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/141316?lang=en&region=us
# **********
# Name: Sean Johnson
# Team: Toronto FC
# League: MLS
# Position: Goalkeeper
# Jersey Number: 1
# Goals: 0
# Assists: 0
# Yellow Cards: 1
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 53
# Clean Sheets: 6
# Goals Against: 23
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/141316.png
# Height: 6' 3"
# Weight: 214 lbs
# Birthdate: 1989-05-31T07:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/141584?lang=en&region=us
# **********
# Name: Arnaud Souquet
# Team: Chicago Fire FC
# League: MLS
# Position: Defender
# Jersey Number: 2
# Goals: 0
# Assists: 3
# Yellow Cards: 5
# Red Cards: 1
# Shots: 9
# Shots on Goal: 2
# Saves: 7
# Clean Sheets: 5
# Goals Against: 27
# Image URL: N/A
# Height: 5' 10"
# Weight: 159 lbs
# Birthdate: 1992-02-12T08:00Z
# Nationality: France
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/141815?lang=en&region=us
# **********
# Name: Abdoulaye Cissoko
# Team: Seattle Sounders FC
# League: MLS
# Position: Defender
# Jersey Number: 92
# Goals: 0
# Assists: 0
# Yellow Cards: 1
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 1
# Goals Against: 0
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/141815.png
# Height: 6' 2"
# Weight: 192 lbs
# Birthdate: 1999-12-27T08:00Z
# Nationality: France
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/144509?lang=en&region=us
# **********
# Name: Gastón Giménez
# Team: Chicago Fire FC
# League: MLS
# Position: Midfielder
# Jersey Number: 30
# Goals: 1
# Assists: 2
# Yellow Cards: 9
# Red Cards: 1
# Shots: 24
# Shots on Goal: 4
# Saves: 17
# Clean Sheets: 5
# Goals Against: 37
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/144509.png
# Height: 6' 2"
# Weight: 181 lbs
# Birthdate: 1991-07-27T07:00Z
# Nationality: Paraguay
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/144821?lang=en&region=us
# **********
# Name: Dixon Arroyo
# Team: Inter Miami CF
# League: MLS
# Position: Midfielder
# Jersey Number: 3
# Goals: 1
# Assists: 0
# Yellow Cards: 4
# Red Cards: 0
# Shots: 13
# Shots on Goal: 4
# Saves: 8
# Clean Sheets: 1
# Goals Against: 31
# Image URL: N/A
# Height: 5' 10"
# Weight: 161 lbs
# Birthdate: 1992-06-01T07:00Z
# Nationality: Ecuador
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/146067?lang=en&region=us
# **********
# Name: Teal Bunbury
# Team: Nashville SC
# League: MLS
# Position: Forward
# Jersey Number: 12
# Goals: 3
# Assists: 1
# Yellow Cards: 7
# Red Cards: 0
# Shots: 42
# Shots on Goal: 8
# Saves: 2
# Clean Sheets: 1
# Goals Against: 15
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/146067.png
# Height: 6' 2"
# Weight: 174 lbs
# Birthdate: 1990-02-27T08:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/146355?lang=en&region=us
# **********
# Name: Andy Najar
# Team: D.C. United
# League: MLS
# Position: Defender
# Jersey Number: 14
# Goals: 0
# Assists: 0
# Yellow Cards: 3
# Red Cards: 0
# Shots: 11
# Shots on Goal: 1
# Saves: 3
# Clean Sheets: 2
# Goals Against: 17
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/146355.png
# Height: 5' 7"
# Weight: 150 lbs
# Birthdate: 1993-03-16T08:00Z
# Nationality: Honduras
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/146408?lang=en&region=us
# **********
# Name: Steven Beitashour
# Team: Colorado Rapids
# League: MLS
# Position: Defender
# Jersey Number: 33
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 3
# Clean Sheets: 2
# Goals Against: 9
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/146408.png
# Height: 5' 10"
# Weight: 172 lbs
# Birthdate: 1987-02-01T08:00Z
# Nationality: Iran
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/146468?lang=en&region=us
# **********
# Name: Tim Melia
# Team: Sporting Kansas City
# League: MLS
# Position: Goalkeeper
# Jersey Number: 29
# Goals: 0
# Assists: 0
# Yellow Cards: 2
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 44
# Clean Sheets: 4
# Goals Against: 26
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/146468.png
# Height: 6' 1"
# Weight: 207 lbs
# Birthdate: 1986-05-15T07:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/146866?lang=en&region=us
# **********
# Name: Héctor Herrera
# Team: Houston Dynamo FC
# League: MLS
# Position: Midfielder
# Jersey Number: 16
# Goals: 5
# Assists: 18
# Yellow Cards: 8
# Red Cards: 2
# Shots: 74
# Shots on Goal: 20
# Saves: 13
# Clean Sheets: 12
# Goals Against: 33
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/146866.png
# Height: 6' 1"
# Weight: 174 lbs
# Birthdate: 1990-04-19T07:00Z
# Nationality: Mexico
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/147197?lang=en&region=us
# **********
# Name: Bryan Oviedo
# Team: Real Salt Lake
# League: MLS
# Position: Defender
# Jersey Number: 3
# Goals: 0
# Assists: 5
# Yellow Cards: 4
# Red Cards: 0
# Shots: 13
# Shots on Goal: 6
# Saves: 11
# Clean Sheets: 5
# Goals Against: 34
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/147197.png
# Height: 5' 8"
# Weight: 130 lbs
# Birthdate: 1990-02-18T08:00Z
# Nationality: Costa Rica
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/147256?lang=en&region=us
# **********
# Name: Robin Jansson
# Team: Orlando City SC
# League: MLS
# Position: Defender
# Jersey Number: 6
# Goals: 0
# Assists: 0
# Yellow Cards: 5
# Red Cards: 0
# Shots: 6
# Shots on Goal: 1
# Saves: 32
# Clean Sheets: 11
# Goals Against: 37
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/147256.png
# Height: 6' 2"
# Weight: 192 lbs
# Birthdate: 1991-11-15T08:00Z
# Nationality: Sweden
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/148306?lang=en&region=us
# **********
# Name: Felipe Gutiérrez
# Team: Sporting Kansas City
# League: MLS
# Position: Midfielder
# Jersey Number: 13
# Goals: 0
# Assists: 0
# Yellow Cards: 1
# Red Cards: 0
# Shots: 7
# Shots on Goal: 2
# Saves: 0
# Clean Sheets: 0
# Goals Against: 6
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/148306.png
# Height: 5' 9"
# Weight: 152 lbs
# Birthdate: 1990-10-08T07:00Z
# Nationality: Chile
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/148320?lang=en&region=us
# **********
# Name: Héber
# Team: Seattle Sounders FC
# League: MLS
# Position: Forward
# Jersey Number: 19
# Goals: 2
# Assists: 1
# Yellow Cards: 0
# Red Cards: 0
# Shots: 37
# Shots on Goal: 12
# Saves: 0
# Clean Sheets: 3
# Goals Against: 13
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/148320.png
# Height: 5' 11"
# Weight: 170 lbs
# Birthdate: 1991-08-10T07:00Z
# Nationality: Brazil
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/148356?lang=en&region=us
# **********
# Name: Diego Luna
# Team: Real Salt Lake
# League: MLS
# Position: Midfielder
# Jersey Number: 26
# Goals: 7
# Assists: 3
# Yellow Cards: 1
# Red Cards: 0
# Shots: 26
# Shots on Goal: 12
# Saves: 3
# Clean Sheets: 1
# Goals Against: 19
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/148356.png
# Height: 5' 8"
# Weight: 185 lbs
# Birthdate: 2003-09-07T07:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/148614?lang=en&region=us
# **********
# Name: Asier Illarramendi
# Team: FC Dallas
# League: MLS
# Position: Midfielder
# Jersey Number: 14
# Goals: 0
# Assists: 1
# Yellow Cards: 5
# Red Cards: 0
# Shots: 4
# Shots on Goal: 0
# Saves: 5
# Clean Sheets: 2
# Goals Against: 12
# Image URL: N/A
# Height: 5' 10"
# Weight: 163 lbs
# Birthdate: 1990-03-08T08:00Z
# Nationality: Spain
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/150185?lang=en&region=us
# **********
# Name: Ilie Sánchez
# Team: LAFC
# League: MLS
# Position: Midfielder
# Jersey Number: 6
# Goals: 1
# Assists: 3
# Yellow Cards: 7
# Red Cards: 0
# Shots: 14
# Shots on Goal: 4
# Saves: 9
# Clean Sheets: 9
# Goals Against: 34
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/150185.png
# Height: 6' 0"
# Weight: 172 lbs
# Birthdate: 1990-11-21T08:00Z
# Nationality: Spain
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/150259?lang=en&region=us
# **********
# Name: Doneil Henry
# Team: Minnesota United FC
# League: MLS
# Position: Defender
# Jersey Number: 5
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/150259.png
# Height: 6' 2"
# Weight: 181 lbs
# Birthdate: 1993-04-20T07:00Z
# Nationality: Canada
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/150334?lang=en&region=us
# **********
# Name: Pedro Gallese
# Team: Orlando City SC
# League: MLS
# Position: Goalkeeper
# Jersey Number: 1
# Goals: 0
# Assists: 0
# Yellow Cards: 4
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 85
# Clean Sheets: 12
# Goals Against: 32
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/150334.png
# Height: 6' 2"
# Weight: 172 lbs
# Birthdate: 1990-02-23T08:00Z
# Nationality: Peru
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/150409?lang=en&region=us
# **********
# Name: João Klauss
# Team: St. Louis CITY SC
# League: MLS
# Position: Forward
# Jersey Number: 9
# Goals: 10
# Assists: 4
# Yellow Cards: 1
# Red Cards: 0
# Shots: 47
# Shots on Goal: 23
# Saves: 1
# Clean Sheets: 3
# Goals Against: 22
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/150409.png
# Height: 6' 3"
# Weight: 183 lbs
# Birthdate: 1997-03-01T08:00Z
# Nationality: Brazil
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/151788?lang=en&region=us
# **********
# Name: Serhiy Kryvtsov
# Team: Inter Miami CF
# League: MLS
# Position: Defender
# Jersey Number: 27
# Goals: 1
# Assists: 0
# Yellow Cards: 5
# Red Cards: 0
# Shots: 5
# Shots on Goal: 1
# Saves: 20
# Clean Sheets: 4
# Goals Against: 33
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/151788.png
# Height: 6' 1"
# Weight: 183 lbs
# Birthdate: 1991-03-15T08:00Z
# Nationality: Ukraine
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/152168?lang=en&region=us
# **********
# Name: Carles Gil
# Team: New England Revolution
# League: MLS
# Position: Midfielder
# Jersey Number: 10
# Goals: 11
# Assists: 15
# Yellow Cards: 7
# Red Cards: 0
# Shots: 77
# Shots on Goal: 29
# Saves: 1
# Clean Sheets: 6
# Goals Against: 39
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/152168.png
# Height: 5' 7"
# Weight: 141 lbs
# Birthdate: 1992-11-22T08:00Z
# Nationality: Spain
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/152660?lang=en&region=us
# **********
# Name: Rudy Camacho
# Team: Columbus Crew
# League: MLS
# Position: Defender
# Jersey Number: 4
# Goals: 1
# Assists: 0
# Yellow Cards: 8
# Red Cards: 1
# Shots: 11
# Shots on Goal: 4
# Saves: 15
# Clean Sheets: 11
# Goals Against: 36
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/152660.png
# Height: 6' 1"
# Weight: 172 lbs
# Birthdate: 1991-03-05T08:00Z
# Nationality: France
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/152732?lang=en&region=us
# **********
# Name: Jesús Jiménez
# Team: FC Dallas
# League: MLS
# Position: Forward
# Jersey Number: 9
# Goals: 0
# Assists: 3
# Yellow Cards: 1
# Red Cards: 0
# Shots: 17
# Shots on Goal: 7
# Saves: 0
# Clean Sheets: 0
# Goals Against: 11
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/152732.png
# Height: 6' 0"
# Weight: 181 lbs
# Birthdate: 1993-11-05T08:00Z
# Nationality: Spain
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/152740?lang=en&region=us
# **********
# Name: Josh Williams
# Team: Columbus Crew
# League: MLS
# Position: Defender
# Jersey Number: 3
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://a.espncdn.com/i/headshots/soccer/players/full/152740.png
# Height: 6' 3"
# Weight: 183 lbs
# Birthdate: 1988-04-18T07:00Z
# Nationality: USA
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/usa.1/seasons/2023/athletes/153289?lang=en&region=us
# **********
# Name: Alfredo Morales
# Team: New York City FC
# League: MLS
# Position: Midfielder
# Jersey Number: 7
# Goals: 0
# Assists: 1
# Yellow Cards: 3
# Red Cards: 0
# Shots: 11
# Shots on Goal: 1
# Saves: 4
# Clean Sheets: 3
# Goals Against: 14
# ...
# **********
# Name: Chukwubuikem Ikwuemesi
# Team: Salernitana
# League: Serie A
# Position: Forward
# Jersey Number: 22
# Goals: 1
# Assists: 1
# Yellow Cards: 2
# Red Cards: 0
# Shots: 7
# Shots on Goal: 2
# Saves: 1
# Clean Sheets: 0
# Goals Against: 6
# Image URL: https://img.legaseriea.it/vimages/64f24436/IKWUEM.png
# Height: 6' 5"
# Weight: N/A
# Birthdate: 2001-08-05T07:00Z
# Nationality: Nigeria
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/365771?lang=en&region=us
# **********
# Name: Zinedin Smajlovic
# Team: Lecce
# League: Serie A
# Position: Defender
# Jersey Number: 26
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/64e38312/SMJNDN.png
# Height: 6' 3"
# Weight: N/A
# Birthdate: 2003-12-20T08:00Z
# Nationality: Sweden
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/365837?lang=en&region=us
# **********
# Name: Kevin Zeroli
# Team: AC Milan
# League: Serie A
# Position: Midfielder
# Jersey Number: 85
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/
# Height: N/A
# Weight: N/A
# Birthdate: 2005-01-11T08:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/366342?lang=en&region=us
# **********
# Name: Giacomo Stabile
# Team: Internazionale
# League: Serie A
# Position: Defender
# Jersey Number: 44
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/64e38598/STBGCM.png
# Height: 6' 2"
# Weight: N/A
# Birthdate: 2005-04-12T07:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/366428?lang=en&region=us
# **********
# Name: Alessandro Calligaris
# Team: Internazionale
# League: Serie A
# Position: Goalkeeper
# Jersey Number: 40
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/
# Height: N/A
# Weight: N/A
# Birthdate: 2005-03-07T08:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/366509?lang=en&region=us
# **********
# Name: Kenan Yildiz
# Team: Juventus
# League: Serie A
# Position: Forward
# Jersey Number: 15
# Goals: 0
# Assists: 0
# Yellow Cards: 1
# Red Cards: 0
# Shots: 1
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/64e38049/YLDKNN.png
# Height: 6' 1"
# Weight: N/A
# Birthdate: 2005-05-04T07:00Z
# Nationality: N/A
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/366510?lang=en&region=us
# **********
# Name: Giovanni Daffara
# Team: Juventus
# League: Serie A
# Position: Goalkeeper
# Jersey Number: 38
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/
# Height: 6' 0"
# Weight: N/A
# Birthdate: 2004-12-05T08:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/366781?lang=en&region=us
# **********
# Name: Patrick Dorgu
# Team: Lecce
# League: Serie A
# Position: Defender
# Jersey Number: 13
# Goals: 0
# Assists: 0
# Yellow Cards: 3
# Red Cards: 0
# Shots: 1
# Shots on Goal: 0
# Saves: 3
# Clean Sheets: 0
# Goals Against: 6
# Image URL: https://img.legaseriea.it/vimages/64e38352/DRGRCK.png
# Height: 6' 1"
# Weight: N/A
# Birthdate: 2004-10-26T07:00Z
# Nationality: Denmark
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/366978?lang=en&region=us
# **********
# Name: Steven Shpendi
# Team: Empoli
# League: Serie A
# Position: Forward
# Jersey Number: 7
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 3
# Shots on Goal: 2
# Saves: 1
# Clean Sheets: 0
# Goals Against: 4
# Image URL: https://img.legaseriea.it/vimages/64e38733/SHPTVN.png
# Height: 5' 11"
# Weight: N/A
# Birthdate: 2003-05-19T07:00Z
# Nationality: Albania
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/367167?lang=en&region=us
# **********
# Name: Tomasso Martinelli
# Team: Fiorentina
# League: Serie A
# Position: Goalkeeper
# Jersey Number: 30
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/64e381f5/MRTMMS.png
# Height: 6' 4"
# Weight: N/A
# Birthdate: 2006-01-06T08:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/367168?lang=en&region=us
# **********
# Name: Pietro Comuzzo
# Team: Fiorentina
# League: Serie A
# Position: Defender
# Jersey Number: 37
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/64e381eb/CMZPTR.png
# Height: N/A
# Weight: N/A
# Birthdate: 2005-02-20T08:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/367436?lang=en&region=us
# **********
# Name: Tommaso Corazza
# Team: Bologna
# League: Serie A
# Position: Defender
# Jersey Number: 16
# Goals: 0
# Assists: 0
# Yellow Cards: 1
# Red Cards: 0
# Shots: 1
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 1
# Image URL: https://img.legaseriea.it/vimages/64e399a4/CRZMMS.png
# Height: 5' 9"
# Weight: N/A
# Birthdate: 2004-06-29T07:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/367445?lang=en&region=us
# **********
# Name: David Pejicic
# Team: Udinese
# League: Serie A
# Position: Midfielder
# Jersey Number: 79
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/64e3856a/PJCDVD.png
# Height: N/A
# Weight: N/A
# Birthdate: 2007-06-14T07:00Z
# Nationality: Slovenia
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/367644?lang=en&region=us
# **********
# Name: Daniel Macej
# Team: Frosinone
# League: Serie A
# Position: Defender
# Jersey Number: 28
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/64e8996a/MCJDNL.png
# Height: N/A
# Weight: N/A
# Birthdate: 2004-04-29T07:00Z
# Nationality: Czechia
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/367646?lang=en&region=us
# **********
# Name: Matjaz Kamensek-Pahic
# Team: Frosinone
# League: Serie A
# Position: Defender
# Jersey Number: 13
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/
# Height: 6' 2"
# Weight: N/A
# Birthdate: 2004-07-04T07:00Z
# Nationality: Slovenia
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/367648?lang=en&region=us
# **********
# Name: Samuel Nwachukwu
# Team: Udinese
# League: Serie A
# Position: Defender
# Jersey Number: 83
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/
# Height: N/A
# Weight: N/A
# Birthdate: 2005-11-04T08:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/367649?lang=en&region=us
# **********
# Name: Bor Zunec
# Team: Udinese
# League: Serie A
# Position: Midfielder
# Jersey Number: 71
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/
# Height: N/A
# Weight: N/A
# Birthdate: 2005-06-30T07:00Z
# Nationality: Slovenia
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/367735?lang=en&region=us
# **********
# Name: Siren Diao
# Team: Hellas Verona
# League: Serie A
# Position: Forward
# Jersey Number: 21
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/64e38135/DIAOSI.png
# Height: 6' 2"
# Weight: N/A
# Birthdate: 2005-01-21T08:00Z
# Nationality: Spain
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/367736?lang=en&region=us
# **********
# Name: Nicola Patanè
# Team: Hellas Verona
# League: Serie A
# Position: Midfielder
# Jersey Number: 28
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/
# Height: N/A
# Weight: N/A
# Birthdate: 2004-03-25T08:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/367740?lang=en&region=us
# **********
# Name: Zanos Savva
# Team: Torino
# League: Serie A
# Position: Forward
# Jersey Number: 79
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/
# Height: 6' 2"
# Weight: N/A
# Birthdate: 2005-11-26T08:00Z
# Nationality: Cyprus
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/367742?lang=en&region=us
# **********
# Name: Matteo Brezzo
# Team: Torino
# League: Serie A
# Position: Goalkeeper
# Jersey Number: 22
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/64e38375/BRZMT1.png
# Height: N/A
# Weight: N/A
# Birthdate: 2005-06-13T07:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/367861?lang=en&region=us
# **********
# Name: Alejandro Jiménez Sánchez
# Team: AC Milan
# League: Serie A
# Position: Defender
# Jersey Number: 74
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/
# Height: 5' 7"
# Weight: N/A
# Birthdate: 2005-05-08T07:00Z
# Nationality: Spain
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/368357?lang=en&region=us
# **********
# Name: Emanuele Elia
# Team: Salernitana
# League: Serie A
# Position: Midfielder
# Jersey Number: 40
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/64f2445c/ELIAMA.png
# Height: 6' 3"
# Weight: N/A
# Birthdate: 2004-12-19T08:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/368432?lang=en&region=us
# **********
# Name: Joel Malusà
# Team: Udinese
# League: Serie A
# Position: Goalkeeper
# Jersey Number: 72
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/
# Height: N/A
# Weight: N/A
# Birthdate: 2007-03-28T07:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/368786?lang=en&region=us
# **********
# Name: Mateus Lusuardi
# Team: Frosinone
# League: Serie A
# Position: Defender
# Jersey Number: 47
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/64e89923/LSRMTS.png
# Height: 6' 3"
# Weight: N/A
# Birthdate: 2004-01-08T08:00Z
# Nationality: Brazil
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/369000?lang=en&region=us
# **********
# Name: Tito Gasperini
# Team: Bologna
# League: Serie A
# Position: Goalkeeper
# Jersey Number: 50
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/65081dca/GSPNTT.png
# Height: N/A
# Weight: N/A
# Birthdate: 2006-03-09T08:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/369003?lang=en&region=us
# **********
# Name: Saná Fernandes
# Team: Lazio
# League: Serie A
# Position: Forward
# Jersey Number: 70
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/65081d80/FRNSNA.png
# Height: 5' 5"
# Weight: N/A
# Birthdate: 2006-03-10T08:00Z
# Nationality: Portugal
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/371813?lang=en&region=us
# **********
# Name: Alessandro Scacchetti
# Team: Sassuolo
# League: Serie A
# Position: Goalkeeper
# Jersey Number: 34
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/
# Height: N/A
# Weight: N/A
# Birthdate: 2005-02-22T08:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/372785?lang=en&region=us
# **********
# Name: Francesco D´Alessio
# Team: AS Roma
# League: Serie A
# Position: Midfielder
# Jersey Number: 68
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/
# Height: 6' 0"
# Weight: N/A
# Birthdate: 2004-02-21T08:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/373507?lang=en&region=us
# **********
# Name: Luigi D'Avino
# Team: Napoli
# League: Serie A
# Position: Defender
# Jersey Number: 50
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/
# Height: 6' 1"
# Weight: N/A
# Birthdate: 2005-12-08T08:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/373806?lang=en&region=us
# **********
# Name: João Gabriel E Costa Cesco
# Team: AS Roma
# League: Serie A
# Position: Forward
# Jersey Number: 67
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/
# Height: 5' 10"
# Weight: N/A
# Birthdate: 2005-03-28T08:00Z
# Nationality: Portugal
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/373994?lang=en&region=us
# **********
# Name: Federico Mosca
# Team: Udinese
# League: Serie A
# Position: Goalkeeper
# Jersey Number: 70
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/
# Height: 6' 4"
# Weight: N/A
# Birthdate: 2005-08-08T07:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/374070?lang=en&region=us
# **********
# Name: Nicolò Calabrese
# Team: Hellas Verona
# League: Serie A
# Position: Defender
# Jersey Number: 75
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/
# Height: N/A
# Weight: N/A
# Birthdate: 2004-11-16T08:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/375057?lang=en&region=us
# **********
# Name: Simone Calvani
# Team: Genoa
# League: Serie A
# Position: Goalkeeper
# Jersey Number: 38
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/64e388ea/CLVSMN.png
# Height: N/A
# Weight: N/A
# Birthdate: 2005-05-16T07:00Z
# Nationality: Italy
# http://sports.core.api.espn.com/v2/sports/soccer/leagues/ita.1/seasons/2023/athletes/375065?lang=en&region=us
# **********
# Name: Andrea Bartoccioni
# Team: AC Milan
# League: Serie A
# Position: Goalkeeper
# Jersey Number: 78
# Goals: 0
# Assists: 0
# Yellow Cards: 0
# Red Cards: 0
# Shots: 0
# Shots on Goal: 0
# Saves: 0
# Clean Sheets: 0
# Goals Against: 0
# Image URL: https://img.legaseriea.it/vimages/
# Height: N/A
# Weight: N/A
# Birthdate: 2004-03-14T08:00Z
# Nationality: Italy

# %% [markdown]
# ### Check Success and Export:
# ---

# %%
# Check pulled data length
print (len(names))
# Out:
# 4348

# %%
# Create athlete_statistics dictionary with lists of data
athlete_statistics = {
    "player_name" : names,
    "team" : teams,
    "league" : leagues,
    "position" : positions,
    "jersey_number" : jersey_numbers,
    "goals" : goals,
    "assists" : assists,
    "yellow_cards" : yellow_cards,
    "red_cards" : red_cards,
    "shots" : shots,
    "shots_on_goal" : shots_og,
    "saves" : saves,
    "clean_sheets" : clean_sheets,
    "goals_against" : goals_against,
    "photo_url" : photo_urls,
    "height" : heights,
    "weight" : weights,
    "birthdate" : birthdates,
    "nationality" : nationalities
}

# %%
# View uncleaned dataframe
athelete_stats_df = pd.DataFrame(athlete_statistics)
athelete_stats_df
# Out:
#                      player_name               team   league    position  \
# 0               Patrick Agyemang       Charlotte FC      MLS     Forward
# 1                  David Bingham   Portland Timbers      MLS  Goalkeeper
# 2                Ashley Westwood       Charlotte FC      MLS  Midfielder
# 3                     Sean Davis       Nashville SC      MLS  Midfielder
# 4                    Steve Clark  Houston Dynamo FC      MLS  Goalkeeper
# ...                          ...                ...      ...         ...
# 4343  João Gabriel E Costa Cesco            AS Roma  Serie A     Forward
# 4344              Federico Mosca            Udinese  Serie A  Goalkeeper
# 4345            Nicolò Calabrese      Hellas Verona  Serie A    Defender
# 4346              Simone Calvani              Genoa  Serie A  Goalkeeper
# 4347          Andrea Bartoccioni           AC Milan  Serie A  Goalkeeper
#
#      jersey_number goals assists yellow_cards red_cards shots shots_on_goal  \
# 0               33     2       0            3         0     8             3
# 1                1     0       0            2         0     0             0
# 2                8     3       4            6         0    18             3
# 3               54     0       1            0         0    11             1
# 4               12     0       2            5         0     0             0
# ...            ...   ...     ...          ...       ...   ...           ...
# 4343            67     0       0            0         0     0             0
# 4344            70     0       0            0         0     0             0
# 4345            75     0       0            0         0     0             0
# 4346            38     0       0            0         0     0             0
# 4347            78     0       0            0         0     0             0
#
#      saves clean_sheets goals_against  \
# 0        0            0             6
# 1       49            6            29
# 2        6            6            45
# 3       18            8            21
# 4       90           13            40
# ...    ...          ...           ...
# 4343     0            0             0
# 4344     0            0             0
# 4345     0            0             0
# 4346     0            0             0
# 4347     0            0             0
#
#                                               photo_url  height   weight  \
# 0     https://a.espncdn.com/i/headshots/soccer/playe...   6' 4"  196 lbs
# 1     https://a.espncdn.com/i/headshots/soccer/playe...   6' 2"  183 lbs
# 2     https://a.espncdn.com/i/headshots/soccer/playe...   5' 9"  174 lbs
# 3     https://a.espncdn.com/i/headshots/soccer/playe...   6' 0"  163 lbs
# 4     https://a.espncdn.com/i/headshots/soccer/playe...   6' 2"  190 lbs
# ...                                                 ...     ...      ...
# 4343                 https://img.legaseriea.it/vimages/  5' 10"      N/A
# 4344                 https://img.legaseriea.it/vimages/   6' 4"      N/A
# 4345                 https://img.legaseriea.it/vimages/     N/A      N/A
# 4346  https://img.legaseriea.it/vimages/64e388ea/CLV...     N/A      N/A
# 4347                 https://img.legaseriea.it/vimages/     N/A      N/A
#
#               birthdate nationality
# 0     2000-11-07T08:00Z       Ghana
# 1     1989-10-19T07:00Z         USA
# 2     1990-04-01T08:00Z     England
# 3     1993-02-08T08:00Z         USA
# 4     1986-04-14T08:00Z         USA
# ...                 ...         ...
# 4343  2005-03-28T08:00Z    Portugal
# 4344  2005-08-08T07:00Z       Italy
# 4345  2004-11-16T08:00Z       Italy
# 4346  2005-05-16T07:00Z       Italy
# 4347  2004-03-14T08:00Z       Italy
#
# [4348 rows x 19 columns]

# %%
# Export unclean data to CSV
athelete_stats_df.to_csv ("initial_unclean_csv/complete_unclean_data.csv", encoding='utf8', index=False, header=True)
